# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_w = pd.read_csv("C:\\Users\\anuha\\Downloads\\3Districts_Crop.csv")

# %%
df_w.head(10)
# Out:
#     State_Name District_Name  Crop_Year       Season                   Crop  \
# 0  West Bengal        HOWRAH       2009  Autumn                        Rice
# 1  West Bengal        HOWRAH       2009  Kharif                  Dry ginger
# 2  West Bengal        HOWRAH       2009  Kharif                        Jute
# 3  West Bengal        HOWRAH       2009  Kharif                       Maize
# 4  West Bengal        HOWRAH       2009  Kharif                   Sunflower
# 5  West Bengal        HOWRAH       2009  Kharif                        Urad
# 6  West Bengal        HOWRAH       2009  Rabi                          Gram
# 7  West Bengal        HOWRAH       2009  Rabi                       Khesari
# 8  West Bengal        HOWRAH       2009  Rabi                        Masoor
# 9  West Bengal        HOWRAH       2009  Rabi         Peas & beans (Pulses)
#
#    Area  Production  Temperature  Rainfall  Humidity  Sun hours
# 0  3652      8259.0         27.0     395.0      85.0        8.0
# ...

# %%
df_w = df_w.iloc[:, 7:]

# %%
df_w
# Out:
#      Temperature  Rainfall  Humidity  Sun hours
# 0          27.00     395.0      85.0       8.00
# 1          28.00    1369.0      85.0       8.50
# 2          28.00    1369.0      85.0       8.50
# 3          28.00    1369.0      85.0       8.50
# 4          28.00    1369.0      85.0       8.50
# ..           ...       ...       ...        ...
# 809        36.40     243.0      59.0      10.10
# 810        36.40     243.0      59.0      10.10
# 811        36.40     243.0      59.0      10.10
# 812        26.89    1601.0      79.1       8.90
# 813        17.20      43.0      61.1       9.23
#
# [814 rows x 4 columns]

# %%
df_a= pd.read_csv("E:\\farmoid\\new_Clean_India.csv")

# %%
df_a
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 242356                  West Bengal       PURULIA       2014  Summer
# 242357                  West Bengal       PURULIA       2014  Summer
# 242358                  West Bengal       PURULIA       2014  Whole Year
# 242359                  West Bengal       PURULIA       2014  Winter
# 242360                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production      Yield    Months
# ...

# %%
common_keys = ['State_Name', 'District_Name', 'Crop_Year','Season',	'Crop',	'Area', 'Production', 'Yield', 'Months']

# %%
df_m= pd.concat([df_w.reset_index(drop=True), df_a.reset_index(drop=True)], axis=1)

# %%
df_m
# Out:
#         Temperature  Rainfall  Humidity  Sun hours  \
# 0              27.0     395.0      85.0        8.0
# 1              28.0    1369.0      85.0        8.5
# 2              28.0    1369.0      85.0        8.5
# 3              28.0    1369.0      85.0        8.5
# 4              28.0    1369.0      85.0        8.5
# ...             ...       ...       ...        ...
# 242356          NaN       NaN       NaN        NaN
# 242357          NaN       NaN       NaN        NaN
# 242358          NaN       NaN       NaN        NaN
# 242359          NaN       NaN       NaN        NaN
# 242360          NaN       NaN       NaN        NaN
#
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# ...

# %%
columns = list(df_m.columns)
columns = columns[4:] + columns[:4]
df = df_m[columns]

# %%
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 242356                  West Bengal       PURULIA       2014  Summer
# 242357                  West Bengal       PURULIA       2014  Summer
# 242358                  West Bengal       PURULIA       2014  Whole Year
# 242359                  West Bengal       PURULIA       2014  Winter
# 242360                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production      Yield    Months  \
# ...

# %%
df_apple= pd.read_csv("E:\\farmoid\\New india App\\new_final_apple.csv")

# %%
df_merge = pd.concat([df, df_apple], axis=0)

# %%
df_merge = df_merge.reset_index(drop=True)

# %%
df_merge
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 242536           Jammu and Kashmir        PULWAMA       2015  Autumn
# 242537           Jammu and Kashmir        PULWAMA       2016  Autumn
# 242538           Jammu and Kashmir        PULWAMA       2017  Autumn
# 242539           Jammu and Kashmir        PULWAMA       2018  Autumn
# 242540           Jammu and Kashmir        PULWAMA       2019  Autumn
#
#                        Crop     Area  Production     Yield     Months  \
# ...

# %%
df= df_merge

# %%
df.shape
# Out:
# (242541, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242541 entries, 0 to 242540
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     242541 non-null  object
#  1   District_Name  242541 non-null  object
#  2   Crop_Year      242541 non-null  int64
#  3   Season         242541 non-null  object
#  4   Crop           242541 non-null  object
#  5   Area           242541 non-null  float64
#  6   Production     242541 non-null  float64
#  7   Yield          242541 non-null  float64
#  8   Months         242541 non-null  object
#  9   Temperature    994 non-null     float64
#  10  Rainfall       994 non-null     float64
#  11  Humidity       994 non-null     float64
#  12  Sun hours      994 non-null     float64
# dtypes: float64(7), int64(1), object(5)
# memory usage: 24.1+ MB

# %%
df.describe()
# Out:
#            Crop_Year          Area    Production          Yield  Temperature  \
# count  242541.000000  2.425410e+05  2.425410e+05  242541.000000   994.000000
# mean     2005.628896  1.216744e+04  5.821775e+05      41.619950    25.819256
# std         4.960099  5.083906e+04  1.705948e+07     817.270102     4.149832
# min      1997.000000  0.000000e+00  0.000000e+00       0.000000    16.400000
# 25%      2002.000000  8.700000e+01  8.800000e+01       0.513966    22.100000
# 50%      2006.000000  6.040000e+02  7.310000e+02       1.000000    26.400000
# 75%      2010.000000  4.560000e+03  7.065000e+03       2.358696    28.600000
# max      2019.000000  8.580100e+06  1.250800e+09   88000.000000    36.400000
#
#           Rainfall    Humidity   Sun hours
# count   994.000000  994.000000  994.000000
# mean    703.001207   72.941459    8.989990
# std     610.208366    7.985799    0.488324
# min      42.000000   53.000000    7.800000
# 25%     208.000000   67.000000    8.700000
# ...

# %%
df.isnull().sum()
# Out:
# State_Name            0
# District_Name         0
# Crop_Year             0
# Season                0
# Crop                  0
# Area                  0
# Production            0
# Yield                 0
# Months                0
# Temperature      241547
# Rainfall         241547
# Humidity         241547
# Sun hours        241547
# dtype: int64

# %%
# Fill NaN values in specific columns
df['Temperature'].fillna(df['Temperature'].mean(), inplace=True)

# %%
df['Rainfall'].fillna(df['Rainfall'].mean(), inplace=True)

# %%
df['Humidity'].fillna(df['Humidity'].mean(), inplace=True)

# %%
df['Sun hours'].fillna(df['Sun hours'].mean(), inplace=True)

# %%
df
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 242536           Jammu and Kashmir        PULWAMA       2015  Autumn
# 242537           Jammu and Kashmir        PULWAMA       2016  Autumn
# 242538           Jammu and Kashmir        PULWAMA       2017  Autumn
# 242539           Jammu and Kashmir        PULWAMA       2018  Autumn
# 242540           Jammu and Kashmir        PULWAMA       2019  Autumn
#
#                        Crop     Area  Production     Yield     Months  \
# ...

# %%
df.isnull().sum()
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# Yield            0
# Months           0
# Temperature      0
# Rainfall         0
# Humidity         0
# Sun hours        0
# dtype: int64

# %%
df["Season"].value_counts()
# Out:
# Kharif         94283
# Rabi           66160
# Whole Year     56127
# Summer         14829
# Winter          6068
# Autumn          5074
# Name: Season, dtype: int64

# %%
df.to_csv('new_Clean_India_merged.csv', index=False)

# %%
df["Crop"].value_counts()
# Out:
# Rice                 15082
# Maize                13787
# Moong(Green Gram)    10106
# Urad                  9710
# Sesamum               8821
#                      ...
# Pear                     6
# Plums                    6
# Litchi                   6
# Peach                    4
# Other Dry Fruit          1
# Name: Crop, Length: 124, dtype: int64

# %%
df['Crop'].unique()
# Out:
# array(['Arecanut', 'Other Kharif pulses', 'Rice', 'Banana', 'Cashewnut',
#        'Coconut ', 'Dry ginger', 'Sugarcane', 'Sweet potato', 'Tapioca',
#        'Black pepper', 'Dry chillies', 'other oilseeds', 'Turmeric',
#        'Maize', 'Moong(Green Gram)', 'Urad', 'Arhar/Tur', 'Groundnut',
#        'Sunflower', 'Bajra', 'Castor seed', 'Cotton(lint)', 'Horse-gram',
#        'Jowar', 'Korra', 'Ragi', 'Tobacco', 'Gram', 'Wheat', 'Masoor',
#        'Sesamum', 'Linseed', 'Safflower', 'Onion', 'other misc. pulses',
#        'Samai', 'Small millets', 'Coriander', 'Potato',
#        'Other  Rabi pulses', 'Soyabean', 'Beans & Mutter(Vegetable)',
#        'Bhindi', 'Brinjal', 'Citrus Fruit', 'Cucumber', 'Grapes', 'Mango',
#        'Orange', 'other fibres', 'Other Fresh Fruits', 'Other Vegetables',
#        'Papaya', 'Pome Fruit', 'Tomato', 'Mesta', 'Cowpea(Lobia)',
#        'Lemon', 'Pome Granet', 'Sapota', 'Cabbage', 'Rapeseed &Mustard',
# ...

# %%
crop_list = [
    'Apple', 'Pear', 'Peach', 'Plum', 'Grapes', 'Citrus fruit', 'Mango', 'Banana',
    'Tomato', 'Potato', ' Black Pepper', 'Cucumber','Water Melon', 'Cabbage',
    'Cauliflower','Peas (vegetable)', 'Peas & beans (Pulses)', 'Beans & Mutter(Vegetable)', 'Carrot', 'Beet Root', 'Turnip',
    'Sunflower', 'Dry chillies'
]

# Filter the DataFrame to include only the specified crops
fil = df[df['Crop'].isin(crop_list)]

# %%
fil
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 20      Andaman and Nicobar Islands      NICOBARS       2002  Whole Year
# 24      Andaman and Nicobar Islands      NICOBARS       2002  Whole Year
# 29      Andaman and Nicobar Islands      NICOBARS       2003  Whole Year
# 33      Andaman and Nicobar Islands      NICOBARS       2003  Whole Year
# ...                             ...           ...        ...          ...
# 242536           Jammu and Kashmir        PULWAMA       2015  Autumn
# 242537           Jammu and Kashmir        PULWAMA       2016  Autumn
# 242538           Jammu and Kashmir        PULWAMA       2017  Autumn
# 242539           Jammu and Kashmir        PULWAMA       2018  Autumn
# 242540           Jammu and Kashmir        PULWAMA       2019  Autumn
#
#                 Crop     Area  Production     Yield     Months  Temperature  \
# ...

# %%
fil.shape
# Out:
# (28261, 13)

# %%
fil.duplicated().sum()
# Out:
# 0

# %%
fil.skew()
# Out:
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\3090438620.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   fil.skew()
# Crop_Year       0.066715
# Area            9.103796
# Production     13.208020
# Yield           3.003541
# Temperature     0.814670
# Rainfall        5.983645
# Humidity        6.120094
# Sun hours       2.092342
# dtype: float64

# %%
# Apply log transformation to reduce skewness
fil['Area'] = np.log1p(fil['Area'])  # log1p(x) computes log(1 + x) to handle zeros gracefully
fil['Production'] = np.log1p(fil['Production'])
fil['Yield'] = np.log1p(fil['Yield'])
# Out:
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\3703901959.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil['Area'] = np.log1p(fil['Area'])  # log1p(x) computes log(1 + x) to handle zeros gracefully
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\3703901959.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil['Production'] = np.log1p(fil['Production'])
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\3703901959.py:4: SettingWithCopyWarning:
# ...

# %%
# Apply square root transformation
fil['Temperature'] = np.sqrt(fil['Temperature'])
fil['Sun hours'] = np.sqrt(fil['Sun hours'])
# Out:
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\3348726276.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil['Temperature'] = np.sqrt(fil['Temperature'])
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\3348726276.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil['Sun hours'] = np.sqrt(fil['Sun hours'])

# %%
from sklearn.preprocessing import PowerTransformer

# Apply Yeo-Johnson transformation
pt = PowerTransformer(method='yeo-johnson')
fil['Rainfall'] = pt.fit_transform(fil[['Rainfall']])
# Out:
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\387705363.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil['Rainfall'] = pt.fit_transform(fil[['Rainfall']])

# %%
fil['Humidity'] = np.sqrt(fil['Humidity'])
fil['Humidity'] = np.log1p(fil['Humidity'])
# Out:
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\3148360735.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil['Humidity'] = np.sqrt(fil['Humidity'])
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\3148360735.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil['Humidity'] = np.log1p(fil['Humidity'])

# %%
fil.skew()
# Out:
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\3090438620.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   fil.skew()
# Crop_Year      0.066715
# Area          -0.202752
# Production    -0.100864
# Yield          0.700067
# Temperature   -1.815882
# Rainfall       2.866985
# Humidity       3.263176
# Sun hours      1.318414
# dtype: float64

# %%
fil.to_csv('new_Clean_horticulture.csv', index=False)

# %% [markdown]
# 1. univariate

# %%
plt.figure(figsize=(8, 6)) 

plt.hist(fil['Area'],bins=20, color='skyblue', edgecolor='black')

# Add title and labels
plt.title('Distribution of Area')
plt.xlabel('Area')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Filter out non-finite values from 'Yield' column
yield_values = fil['Yield']
valid_yield_values = yield_values[np.isfinite(yield_values)]

# Plot histogram for valid 'Yield' values
plt.figure(figsize=(8, 6)) 
plt.hist(valid_yield_values, bins=20, color='skyblue', edgecolor='black')

# Add title and labels
plt.title('Distribution of Yield')
plt.xlabel('Yield')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(8, 6)) 

plt.hist(fil['Rainfall'],bins=20, color='skyblue', edgecolor='black')

# Add title and labels
plt.title('Distribution of Rainfall')
plt.xlabel('Rainfall')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=fil, x='Crop_Year', y='Yield', hue='Season')
plt.title("Seasonal Trends in Crop Yield")
plt.xlabel("Year")
plt.ylabel("Yield")
plt.legend(title='Season')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=fil, x='Crop_Year', y='Rainfall', hue='Season')
plt.title("Seasonal Trends in Crop Yield")
plt.xlabel("Year")
plt.ylabel("rainfall")
plt.legend(title='Season')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=fil, x='Months', y='Rainfall', hue='Season')
plt.title("Seasonal Trends in Crop Yield")
plt.xlabel("Months")
plt.ylabel("rainfall")
plt.legend(title='Season')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y =fil['Area'])
plt.title('Boxplot of Area')
plt.xlabel('Area')
# Out:
# Text(0.5, 0, 'Area')

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y =fil['Production'])
plt.title('Boxplot of Production')
plt.xlabel('Production')
# Out:
# Text(0.5, 0, 'Production')

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y =fil['Temperature'])
plt.title('Boxplot of Temperature')
plt.xlabel('Temperature')
# Out:
# Text(0.5, 0, 'Temperature')

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y =fil['Sun hours'])
plt.title('Boxplot of Sunhours')
plt.xlabel('Sun hours')
# Out:
# Text(0.5, 0, 'Sun hours')

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y =fil['Humidity'])
plt.title('Boxplot of Humidity')
plt.xlabel('Humidity')
# Out:
# Text(0.5, 0, 'Humidity')

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y =fil['Rainfall'])
plt.title('Boxplot of Rainfall')
plt.xlabel('Rainfall')
# Out:
# Text(0.5, 0, 'Rainfall')

# %% [markdown]
# 2. Bivariate

# %%
plt.figure(figsize=(10, 6))

# Create a box plot or violin plot to visualize the distribution of 'Yield (A/P)' over different years
sns.barplot(x='Season', y='Area', data=fil)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Add title and labels
plt.title('Area Distribution Over Season')
# Out:
# Text(0.5, 1.0, 'Area Distribution Over Season')

# %%
plt.figure(figsize=(10, 6))

# Create a box plot or violin plot to visualize the distribution of 'Yield (A/P)' over different years
sns.barplot(x='Season', y='Rainfall', data=fil)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Add title and labels
plt.title('Rainfall Distribution Over Season')
# Out:
# Text(0.5, 1.0, 'Rainfall Distribution Over Season')

# %%
plt.figure(figsize=(10,6))

# Create a box plot or violin plot to visualize the distribution of 'Yield (A/P)' over different years
sns.barplot(x='Months', y='Rainfall', data=fil)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Add title and labels
plt.title('rainfall Distribution Over Season')
# Out:
# Text(0.5, 1.0, 'rainfall Distribution Over Season')

# %%
plt.figure(figsize=(10, 6))

# Create a box plot or violin plot to visualize the distribution of 'Yield (A/P)' over different years
sns.barplot(x='Season', y='Production', data=fil)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Add title and labels
plt.title('Production Distribution Over Season')
# Out:
# Text(0.5, 1.0, 'Production Distribution Over Season')

# %%
plt.figure(figsize=(10, 6))

# Create a box plot or violin plot to visualize the distribution of 'Yield (A/P)' over different years
sns.barplot(x='Season', y='Yield', data=fil)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Add title and labels
plt.title('Yield (A/P) Distribution Over Season')
plt.xlabel('Season')
plt.ylabel('Yield')
# Out:
# Text(0, 0.5, 'Yield')

# %%
plt.figure(figsize=(40, 10))

# Create a box plot or violin plot to visualize the distribution of 'Yield (A/P)' over different years
sns.barplot(x='Crop', y='Area', data=fil)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Add title and labels
plt.title('Area Over Crops Name')
plt.xlabel('Crop')
plt.ylabel('Area')
# Out:
# Text(0, 0.5, 'Area')

# %%
plt.figure(figsize=(40, 10))

# Create a box plot or violin plot to visualize the distribution of 'Yield (A/P)' over different years
sns.barplot(x='Crop', y='Yield', data=fil)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Add title and labels
plt.title('Yield Over Crops Name')
plt.xlabel('Crop')
plt.ylabel('yield')
# Out:
# Text(0, 0.5, 'yield')

# %%
plt.figure(figsize=(40, 10))

# Create a box plot or violin plot to visualize the distribution of 'Yield (A/P)' over different years
sns.barplot(x='Crop', y='Production', data=fil)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Add title and labels
plt.title('production Over Crops Name')
plt.xlabel('Crop')
plt.ylabel('Production')
# Out:
# Text(0, 0.5, 'Production')

# %%
plt.figure(figsize=(6, 4))  

# Create a scatter plot for the "Year" and "Yield (A/P)" variables
sns.scatterplot(x='Crop_Year', y='Area', data=fil)

plt.title('Scatter Plot of Year vs Area')  # Set the title of the plot
plt.xlabel('Year')  # Set the label for the x-axis
plt.ylabel('Area')
# Out:
# Text(0, 0.5, 'Area')

# %%
plt.figure(figsize=(6, 4)) 

# Create a scatter plot for the "Year" and "Yield (A/P)" variables
sns.scatterplot(x='Crop_Year', y='Yield', data=fil)

plt.title('Scatter Plot of Year vs Yield (A/P)')  # Set the title of the plot
plt.xlabel('Crop_Year')  # Set the label for the x-axis
plt.ylabel('Yield (A/P)')
# Out:
# Text(0, 0.5, 'Yield (A/P)')

# %%
plt.figure(figsize=(6, 4))  # Set the figure size

# Create a scatter plot for the "Year" and "Yield (A/P)" variables
sns.scatterplot(x='Crop_Year', y='Production', data=fil)

plt.title('Scatter Plot of Year vs Production')  # Set the title of the plot
plt.xlabel('Crop_Year')  # Set the label for the x-axis
plt.ylabel('Production')
# Out:
# Text(0, 0.5, 'Production')

# %%
plt.figure(figsize=(20,15))
sns.barplot(x="State_Name",y="Area",data=fil)
plt.xticks(rotation=90)
plt.title('Bar Plot of State vs Area')
# Out:
# Text(0.5, 1.0, 'Bar Plot of State vs Area')

# %%
plt.figure(figsize=(20,15))
sns.barplot(x="Months",y="Yield",data=fil)
plt.xticks(rotation=90)
plt.title('Bar Plot of State vs Yield')
# Out:
# Text(0.5, 1.0, 'Bar Plot of State vs Yield')

# %% [markdown]
# 3. Multivariate

# %%
correlation = fil.corr()
correlation
# Out:
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\539005707.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = fil.corr()
#              Crop_Year      Area  Production     Yield  Temperature  Rainfall  \
# Crop_Year     1.000000 -0.040586    0.023566  0.065922     0.004606 -0.011229
# Area         -0.040586  1.000000    0.834308  0.112953     0.002775  0.003766
# Production    0.023566  0.834308    1.000000  0.606559     0.005082  0.004244
# Yield         0.065922  0.112953    0.606559  1.000000    -0.000824 -0.001450
# Temperature   0.004606  0.002775    0.005082 -0.000824     1.000000  0.358694
# Rainfall     -0.011229  0.003766    0.004244 -0.001450     0.358694  1.000000
# Humidity     -0.001939  0.008992    0.012770 -0.000793     0.461871  0.715836
# ...

# %%
plt.figure(figsize=(8,6))
sns.heatmap(correlation,annot=True,cmap='crest',linewidths=1.0)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Modelling

# %%
# Handling missing values
fil['Yield'].replace([np.inf, -np.inf], np.nan, inplace=True)
fil.dropna(subset=['Production', 'Yield'], inplace=True)
# Out:
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\3899152302.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil['Yield'].replace([np.inf, -np.inf], np.nan, inplace=True)
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\3899152302.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil.dropna(subset=['Production', 'Yield'], inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

categorical_columns = ['State_Name','District_Name','Season', 'Crop','Months' ]  
for column in categorical_columns:
    fil[column] = label_encoder.fit_transform(fil[column])
# Out:
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\4191385274.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil[column] = label_encoder.fit_transform(fil[column])
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\4191385274.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil[column] = label_encoder.fit_transform(fil[column])
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\4191385274.py:7: SettingWithCopyWarning:
# ...

# %%
fil.drop(columns=['Crop_Year'], inplace=True)
# Out:
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\792194480.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil.drop(columns=['Crop_Year'], inplace=True)

# %%
fil
# Out:
#         State_Name  District_Name  Season  Crop      Area  Production  \
# 3                0            420       4     1  5.176150    6.464588
# 20               0            420       4     1  5.365976    7.153834
# 24               0            420       4     8  6.025866    3.394508
# 29               0            420       4     1  5.587249    7.475339
# 33               0            420       4     8  4.110874    4.634729
# ...            ...            ...     ...   ...       ...         ...
# 242536          12            457       0     0  9.557046   11.889998
# 242537          12            457       0     0  9.567385   11.844306
# 242538          12            457       0     0  9.641343   11.823274
# 242539          12            457       0     0  9.653422   11.838395
# 242540          12            457       0     0  9.666879   12.055907
#
#            Yield  Months  Temperature   Rainfall  Humidity  Sun hours
# ...

# %%
x= fil.drop('Yield',axis=1)
y= fil['Yield']

# %%
# Remove infinite and large values
y.replace([np.inf, -np.inf], np.nan, inplace=True)
x.replace([np.inf, -np.inf], np.nan, inplace=True)

# Drop NaN values
x.dropna(inplace=True)
y.dropna(inplace=True)

# Ensure x and y have the same index
x = x.loc[y.index]
# Out:
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\3886152458.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y.replace([np.inf, -np.inf], np.nan, inplace=True)
# C:\Users\anuha\AppData\Local\Temp\ipykernel_12540\3886152458.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y.dropna(inplace=True)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1234)

# %%
x_train.shape
# Out:
# (19782, 11)

# %%
x_test.shape
# Out:
# (8479, 11)

# %%
y_train.shape
# Out:
# (19782,)

# %%
y_test.shape
# Out:
# (8479,)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.feature_selection import SelectKBest, f_regression

selector = SelectKBest(score_func=f_regression, k=5)
X_train_selected = selector.fit_transform(x_train, y_train)
X_test_selected = selector.transform(x_test)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
# Linear Regression Model
regressor = LinearRegression()
model =regressor.fit(X_train_selected, y_train)

# %%
# Make predictions
y_pred_lr = regressor.predict(X_test_selected)

# %%
# Ensure y_test and y_pred_lr are of the same length
print("y_test shape:", y_test.shape)
print("y_pred_lr shape:", y_pred_lr.shape)
# Out:
# y_test shape: (8479,)
# y_pred_lr shape: (8479,)

# %%
regressor.coef_
# Out:
# array([ 0.00339862,  0.08741608, -0.01282366, -0.58650932,  0.58635368])

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
# Evaluate the model
linear_reg_r2 = r2_score(y_test, y_pred_lr)
linear_reg_mse = mean_squared_error(y_test, y_pred_lr)
print("Linear Regression R2 score:", linear_reg_r2)
print("Linear Regression MSE:", linear_reg_mse)
# Out:
# Linear Regression R2 score: 0.8963387722399668
# Linear Regression MSE: 0.12462953188399008

# %%
plt.scatter(y_test, y_pred_lr)
plt.title("Linear Regression Model")
plt.show()

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regressor_dt = DecisionTreeRegressor(random_state=1234)

# %%
regressor_dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=1234)

# %%
y_pred_dt = regressor_dt.predict(x_test)

# %%
decision_tree_r2 = r2_score(y_test, y_pred_dt)
decision_tree_mse = mean_squared_error(y_test, y_pred_dt)
print("Decision Tree R2 score:", decision_tree_r2)
print("Decision Tree MSE:", decision_tree_mse)
# Out:
# Decision Tree R2 score: 0.9859951844867234
# Decision Tree MSE: 0.016837670547196155

# %%
plt.scatter(y_test, y_pred_dt)
plt.title("Decision Tree Regressor Model")
plt.show()

# %% [markdown]
# # random forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor_rf = RandomForestRegressor(random_state=1234)

# %%
regressor_rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=1234)

# %%
Y_pred_rf=regressor_rf.predict(x_test)

# %%
random_forest_r2 = r2_score(y_test, Y_pred_rf)
random_forest_mse = mean_squared_error(y_test, Y_pred_rf)
print("Random Forest R2 score:", random_forest_r2)
print("Random Forest MSE:", random_forest_mse)
# Out:
# Random Forest R2 score: 0.9943015078514009
# Random Forest MSE: 0.006851167251931024

# %%
plt.scatter(y_test, Y_pred_rf)
plt.title("Random Forest Regressor Model")
plt.show()

# %% [markdown]
# # XG BOOST

# %%
from xgboost import XGBRegressor

# %%
xgb_regressor = XGBRegressor(random_state=1234)

# %%
xgb_regressor.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=1234, ...)

# %%
Y_pred_xg=xgb_regressor.predict(x_test)

# %%
xgboost_r2=r2_score(y_test,Y_pred_xg)
print("r2_score is",xgboost_r2)
xgboost_mse=mean_squared_error(y_test,Y_pred_xg)
print("mse is",xgboost_mse)
# Out:
# r2_score is 0.9969620507339583
# mse is 0.003652457173192707

# %%
plt.scatter(y_test, Y_pred_xg)
plt.title("XG BOOST Regressor Model")
plt.show()

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
regressor_knn = KNeighborsRegressor()

# %%
regressor_knn.fit(X_train_selected, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred_knn = regressor_knn.predict(X_test_selected)

# %%
knn_r2 = r2_score(y_test, y_pred_knn)
knn_mse = mean_squared_error(y_test, y_pred_knn)
print("KNN R2 score:", knn_r2)
print("KNN MSE:", knn_mse)
# Out:
# KNN R2 score: 0.9805846831668108
# KNN MSE: 0.02334259298858748

# %%
# Model Comparison
model_names = ['Linear Regression', 'Decision Tree', 'Random Forest', 'XGBoost', 'KNN']
r2_scores = [linear_reg_r2, decision_tree_r2, random_forest_r2, xgboost_r2, knn_r2]
mse_values = [linear_reg_mse, decision_tree_mse, random_forest_mse, xgboost_mse, knn_mse]

plt.figure(figsize=(15, 8))

# R2 Score Comparison
plt.subplot(1, 2, 1)
plt.bar(model_names, r2_scores, color='skyblue')
plt.title('R2 Score Comparison')
plt.xlabel('Regression Model')
plt.ylabel('R2 Score')

# MSE Comparison
plt.subplot(1, 2, 2)
plt.bar(model_names, mse_values, color='lightgreen')
plt.title('Mean Squared Error Comparison')
plt.xlabel('Regression Model')
plt.ylabel('Mean Squared Error')

plt.show()

# %%
import joblib
from sklearn.ensemble import RandomForestRegressor

# Assuming x_train and y_train are already defined and preprocessed
xgb_regressor = RandomForestRegressor(random_state=1234)
xgb_regressor.fit(x_train, y_train)

# Save the trained model
joblib.dump(xgb_regressor, 'xgb_hort_model_.pkl')
# Out:
# ['xgb_hort_model_.pkl']

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# %%
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
aplist = ['Apple']

# Filter the DataFrame to include only the specified crops
fillet = df[df['Crop'].isin(aplist)]

# %%
fillet
# Out:
#                 State_Name District_Name  Crop_Year       Season   Crop  \
# 176282          Tamil Nadu      DINDIGUL       2002  Whole Year   Apple
# 176349          Tamil Nadu      DINDIGUL       2003  Whole Year   Apple
# 182751          Tamil Nadu  THE NILGIRIS       2002  Whole Year   Apple
# 182798          Tamil Nadu  THE NILGIRIS       2003  Whole Year   Apple
# 242361  Jammu and Kashmir       SRINAGAR       2001  Autumn       Apple
# ...                    ...           ...        ...          ...    ...
# 242536  Jammu and Kashmir        PULWAMA       2015  Autumn       Apple
# 242537  Jammu and Kashmir        PULWAMA       2016  Autumn       Apple
# 242538  Jammu and Kashmir        PULWAMA       2017  Autumn       Apple
# 242539  Jammu and Kashmir        PULWAMA       2018  Autumn       Apple
# 242540  Jammu and Kashmir        PULWAMA       2019  Autumn       Apple
#
#            Area  Production     Yield     Months  Temperature    Rainfall  \
# ...

# %%
df['State_Name'].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir ', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana ',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
import gzip
import pickle

# Path to the pickle file to compress
input_file_path = "xgb_hort_model_.pkl"

# Path to the compressed output file
output_file_path = "xgb_hort_comp_model.pkl.gz"

# Load the data from the pickle file
with open(input_file_path, 'rb') as f:
    data = pickle.load(f)

# Compress and write the data to a gzip-compressed file
with gzip.open(output_file_path, 'wb') as f:
    pickle.dump(data, f)

print("File compressed successfully.")
# Out:
# File compressed successfully.

# %%
dlist = ['KANNUR']

# Filter the DataFrame to include only the specified crops
dis = df[df['District_Name'].isin(dlist)]

# %%
dis
# Out:
#       State_Name District_Name  Crop_Year       Season          Crop  \
# 96955     Kerala        KANNUR       1997  Whole Year       Arecanut
# 96956     Kerala        KANNUR       1997  Whole Year   Black pepper
# 96957     Kerala        KANNUR       1997  Whole Year      Cashewnut
# 96958     Kerala        KANNUR       1997  Whole Year       Coconut
# 96959     Kerala        KANNUR       1997  Whole Year        Tapioca
# ...          ...           ...        ...          ...           ...
# 97216     Kerala        KANNUR       2014  Whole Year      Sugarcane
# 97217     Kerala        KANNUR       2014  Whole Year   Sweet potato
# 97218     Kerala        KANNUR       2014  Whole Year        Tapioca
# 97219     Kerala        KANNUR       2014  Whole Year       Turmeric
# 97220     Kerala        KANNUR       2014  Winter               Rice
#
#             Area  Production      Yield    Months  Temperature    Rainfall  \
# ...

# %%
clist = ['Banana']

# Filter the DataFrame to include only the specified crops
fis = dis[dis['Crop'].isin(clist)]

# %%
fis
# Out:
#       State_Name District_Name  Crop_Year       Season    Crop     Area  \
# 96964     Kerala        KANNUR       1998  Whole Year   Banana  1453.00
# 96978     Kerala        KANNUR       1999  Whole Year   Banana  1840.00
# 96993     Kerala        KANNUR       2000  Whole Year   Banana  2035.00
# 97006     Kerala        KANNUR       2001  Whole Year   Banana  2480.00
# 97019     Kerala        KANNUR       2002  Whole Year   Banana  2445.00
# 97047     Kerala        KANNUR       2003  Whole Year   Banana  2310.00
# 97071     Kerala        KANNUR       2004  Whole Year   Banana  2493.00
# 97085     Kerala        KANNUR       2005  Whole Year   Banana  2554.00
# 97098     Kerala        KANNUR       2006  Whole Year   Banana  2728.00
# 97112     Kerala        KANNUR       2007  Whole Year   Banana  2181.00
# 97125     Kerala        KANNUR       2008  Whole Year   Banana  2340.00
# 97138     Kerala        KANNUR       2009  Whole Year   Banana  2566.00
# ...

# %%
fis.to_csv('kannur_district.csv', index=False)
